# %% [markdown]
# <h1>The 6.3 Magnitude L'Aquila Earthquake on April 6, 2009 in Central Italy</h1>
# <img src=https://upload.wikimedia.org/wikipedia/commons/e/e2/20090406_013242_umbria_quake_intensity.jpg>
# The 2009 L'Aquila earthquake occurred in the region of Abruzzo, in central Italy. The main shock occurred at 03:32 CEST (01:32 UTC) on 6 April 2009, and was rated 5.8 or 5.9 on the Richter magnitude scale and 6.3 on the moment magnitude scale; its epicentre was near L'Aquila, the capital of Abruzzo, which together with surrounding villages suffered the most damage. There have been several thousand foreshocks and aftershocks since December 2008, more than thirty of which had a Richter magnitude greater than 3.5.
#
# The earthquake was felt throughout central Italy; 308 people are known to have died, making this the deadliest earthquake to hit Italy since the 1980 Irpinia earthquake. In a subsequent inquiry of the handling of the disaster, seven members of the Italian National Commission for the Forecast and Prevention of Major Risks were accused of giving "inexact, incomplete and contradictory" information about the danger of the tremors prior to the main quake.On 22 October 2012, six scientists and one ex-government official were convicted of multiple manslaughter for downplaying the likelihood of a major earthquake six days before it took place. They were each sentenced to six years' imprisonment, but the verdict was overturned on 10 November 2014. Criticism was also applied to poor building standards that led to the failure of many modern buildings in a known earthquake zone: an official at Italy's Civil Protection Agency, Franco Barberi, said that "in California, an earthquake like this one would not have killed a single person".

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
client = Client("IRIS")

# %%
endt = UTCDateTime("2009-04-06") 
startt = UTCDateTime("1999-04-06")
maxrad = 1.0
minmag = 2.0
lat = 42.3476
lon = 13.3800

# %%
cat = client.get_events(starttime=startt, endtime=endt, latitude=lat, longitude=lon, 
                        maxradius=maxrad, minmagnitude=minmag, catalog="ISC")
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/http/client.py:580, in HTTPResponse._readall_chunked(self)
#     579     break
# --> 580 value.append(self._safe_read(chunk_left))
#     581 self.chunk_left = 0
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:628, in HTTPResponse._safe_read(self, amt)
#     627 if not chunk:
# --> 628     raise IncompleteRead(b''.join(s), amt)
#     629 s.append(chunk)
#
# IncompleteRead: IncompleteRead(39 bytes read, 21 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 cat = client.get_events(starttime=startt, endtime=endt, latitude=lat, longitude=lon,
#       2                         maxradius=maxrad, minmagnitude=minmag, catalog="ISC")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:548, in Client.get_events(self, starttime, endtime, minlatitude, maxlatitude, minlongitude, maxlongitude, latitude, longitude, minradius, maxradius, mindepth, maxdepth, minmagnitude, maxmagnitude, magnitudetype, eventtype, includeallorigins, includeallmagnitudes, includearrivals, eventid, limit, offset, orderby, catalog, contributor, updatedafter, filename, **kwargs)
#     543 setup_query_dict('event', locs, kwargs)
#     545 url = self._create_url_from_parameters(
#     546     "event", DEFAULT_PARAMETERS['event'], kwargs)
# --> 548 data_stream = self._download(url)
#     549 data_stream.seek(0, 0)
#     550 if filename:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1415, in Client._download(self, url, return_string, data, use_gzip)
#    1414 def _download(self, url, return_string=False, data=None, use_gzip=True):
# -> 1415     code, data = download_url(
#    1416         url, opener=self._url_opener, headers=self.request_headers,
#    1417         debug=self.debug, return_string=return_string, data=data,
#    1418         timeout=self.timeout, use_gzip=use_gzip)
#    1419     raise_on_error(code, data)
#    1420     return data
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1847, in download_url(url, opener, timeout, headers, debug, return_string, data, use_gzip)
#    1844     print("Uncompressing gzipped response for %s" % url)
#    1845 # Cannot directly stream to gzip from urllib!
#    1846 # http://www.enricozini.org/2011/cazzeggio/python-gzip/
# -> 1847 buf = io.BytesIO(url_obj.read())
#    1848 buf.seek(0, 0)
#    1849 f = gzip.GzipFile(fileobj=buf)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:470, in HTTPResponse.read(self, amt)
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#     469     if self.chunked:
# --> 470         return self._readall_chunked()
#     472     if self.length is None:
#     473         s = self.fp.read()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:584, in HTTPResponse._readall_chunked(self)
#     582     return b''.join(value)
#     583 except IncompleteRead:
# --> 584     raise IncompleteRead(b''.join(value))
#
# IncompleteRead: IncompleteRead(186839 bytes read)

# %%
cat.__str__(print_all=True)
# Out:
# '3644 Event(s) in Catalog:\n2009-04-05T22:56:43.890000Z | +42.988,  +13.626 | 2.3  Ml\n2009-04-05T22:39:42.840000Z | +42.339,  +13.376 | 3.3  mb\n2009-04-05T20:48:55.930000Z | +42.339,  +13.365 | 4.0  mb\n2009-04-03T06:43:24.800000Z | +42.313,  +13.368 | 2.5  Ml\n2009-04-03T05:48:03.500000Z | +42.316,  +13.367 | 2.1  Ml\n2009-04-03T05:10:35.400000Z | +42.319,  +13.371 | 2.0  Ml\n2009-04-03T05:08:31.400000Z | +42.316,  +13.371 | 2.0  Ml\n2009-04-03T04:44:42.880000Z | +42.318,  +13.361 | 2.8  Ml\n2009-04-02T11:11:54.200000Z | +42.310,  +13.374 | 2.6  Ml\n2009-04-02T09:46:18.500000Z | +42.351,  +13.374 | 2.1  Ml\n2009-04-01T18:24:17.600000Z | +42.316,  +13.370 | 2.3  Ml\n2009-04-01T17:14:11.300000Z | +42.318,  +13.375 | 2.1  Ml\n2009-04-01T15:15:38.300000Z | +42.343,  +13.365 | 2.3  Ml\n2009-04-01T10:23:28.300000Z | +42.328,  +13.367 | 2.5  Ml\n2009-04-01T05:37:36.200000Z | +42.312,  +13.367 | 2.0  Ml\n2009-04-01T02:56:51.000000Z | +42.319,  +13.366 | 2.1  Ml\n2009-03-31T11:14:10.600000Z | +42.310,  +13.374 | 2.7  Ml\n2009-03-31T06:04:52.300000Z | +42.314,  +13.374 | 2.5  Ml\n2009-03-30T21:57:17.620000Z | +42.331,  +13.371 | 3.1  mb\n2009-03-30T20:19:35.500000Z | +42.316,  +13.376 | 2.6  Ml\n2009-03-30T20:04:45.100000Z | +42.333,  +13.372 | 2.9  ML\n2009-03-30T19:32:51.700000Z | +42.315,  +13.373 | 2.5  Ml\n2009-03-30T19:13:33.300000Z | +42.323,  +13.371 | 2.1  Ml\n2009-03-30T19:08:22.300000Z | +42.289,  +13.367 | 2.1  Ml\n2009-03-30T19:05:28.800000Z | +42.314,  +13.350 | 3.0  mb\n2009-03-30T18:14:21.800000Z | +42.335,  +13.376 | 2.0  Ml\n2009-03-30T17:11:32.900000Z | +42.323,  +13.369 | 2.7  Ml\n2009-03-30T16:57:23.900000Z | +42.324,  +13.369 | 2.3  Ml\n2009-03-30T14:50:01.400000Z | +42.328,  +13.377 | 2.0  Ml\n2009-03-30T14:37:00.000000Z | +42.340,  +13.370 | 2.3  Ml\n2009-03-30T14:33:45.400000Z | +42.336,  +13.376 | 2.0  Ml\n2009-03-30T14:16:05.700000Z | +42.324,  +13.369 | 2.0  Ml\n2009-03-30T14:11:04.510000Z | +42.329,  +13.377 | 2.1  Md\n2009-03-30T14:10:44.300000Z | +42.322,  +13.365 | 2.4  Ml\n2009-03-30T13:43:27.490000Z | +42.324,  +13.376 | 3.4  mb\n2009-03-30T13:41:22.900000Z | +42.332,  +13.364 | 2.0  Md\n2009-03-30T13:38:39.820000Z | +42.339,  +13.351 | 4.3  mb\n2009-03-29T08:43:08.840000Z | +42.032,  +13.988 | 4.1  mb\n2009-03-28T20:31:22.800000Z | +42.347,  +13.370 | 2.4  Ml\n2009-03-28T01:42:41.800000Z | +42.349,  +13.377 | 2.4  Ml\n2009-03-27T18:51:35.300000Z | +41.508,  +13.831 | 2.5  Ml\n2009-03-27T17:01:56.700000Z | +41.520,  +13.814 | 2.3  Ml\n2009-03-27T07:19:30.900000Z | +42.334,  +13.358 | 2.2  Ml\n2009-03-27T03:56:46.100000Z | +42.888,  +13.123 | 2.6  mb\n2009-03-27T01:18:46.500000Z | +41.750,  +12.660 | 2.5  Ml\n2009-03-26T02:10:38.800000Z | +42.344,  +13.377 | 2.0  Ml\n2009-03-23T19:03:18.600000Z | +42.955,  +13.278 | 2.3  ML\n2009-03-22T12:08:02.900000Z | +42.817,  +12.980 | 2.1  Ml\n2009-03-22T07:02:55.400000Z | +42.334,  +13.377 | 2.3  Ml\n2009-03-20T09:41:34.900000Z | +42.951,  +13.243 | 2.1  Md\n2009-03-20T08:40:52.000000Z | +42.024,  +12.945 | 2.2  Ml\n2009-03-18T09:23:09.300000Z | +42.330,  +13.390 | 2.2  Ml\n2009-03-18T05:27:45.530000Z | +42.981,  +13.637 | 2.8  ML\n2009-03-17T08:29:37.500000Z | +43.258,  +13.090 | 2.6  ML\n2009-03-17T01:26:12.900000Z | +41.995,  +14.012 | 2.6  mb\n2009-03-17T01:12:51.710000Z | +42.010,  +14.007 | 3.6  mb\n2009-03-13T15:29:55.700000Z | +42.351,  +13.367 | 2.3  Ml\n2009-03-13T13:49:14.700000Z | +42.342,  +13.422 | 2.0  Ml\n2009-03-13T10:48:30.700000Z | +41.972,  +14.072 | 2.4  Ml\n2009-03-12T11:18:27.800000Z | +42.012,  +12.957 | 2.2  Ml\n2009-03-11T21:55:50.170000Z | +42.335,  +13.368 | 2.9  mb\n2009-03-10T11:25:27.700000Z | +42.341,  +13.373 | 2.1  Ml\n2009-03-10T00:19:40.100000Z | +42.797,  +13.124 | 2.0  Ml\n2009-03-07T19:15:29.600000Z | +42.033,  +13.205 | 2.0  Ml\n2009-03-05T18:55:46.300000Z | +42.366,  +12.662 | 2.5  Ml\n2009-03-05T02:03:04.400000Z | +43.016,  +12.882 | 2.2  Ml\n2009-02-28T05:32:28.200000Z | +43.021,  +12.868 | 2.4  Ml\n2009-02-23T05:47:42 ...

# %%
times = []
mags = []
for event in cat:
    times.append(event.origins[0].time.datetime)
    mags.append(event.magnitudes[0].mag)

# %%
print(times[4],mags[4])
# Out:
# 2009-04-03 05:48:03.500000 2.1

# %%
mtimes = mdates.date2num(times)

# %%
mtimes[4]
# Out:
# 14337.241707175926

# %% [markdown]
# We are going to make a plot that shows the magnitude of all earthquakes in the catalog over time.

# %%
fig1 = plt.subplots(1,1)
plt.plot_date(mtimes,mags,marker='.')
# plt.ylim(2.5, 7)
plt.show()
# Out:
# /var/folders/pl/n9dpnr6j189_tc7zv1jcdnph0000gn/T/ipykernel_3157/3737684298.py:2: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(mtimes,mags,marker='.')

# %%
fig2, axes = plt.subplots(1,1)
axes.hist(mtimes, bins=120)
axes.xaxis.set_major_locator(mdates.YearLocator())
axes.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
